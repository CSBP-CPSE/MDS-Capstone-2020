# %%
import pandas as pd
import numpy as np

# Set options to show dfs in full
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Clean the general LTC data

# %%
# Add a column with name in lower case
df_genLTC = pd.read_csv('webscrape_ltc_general_database.csv')
df_genLTC['cleaned_name'] = df_genLTC['name'].str.lower()

# Adjust names from general LTC database to match names from COVID LTC database
df_genLTC["cleaned_name"].replace({"vision '74 inc.": "vision nursing home", "finlandia hoivakoti nursing home limited": "finlandia hoivakoti nursing home", "pinecrest nursing home - bobcaygeon": "pinecrest nursing home (bobcaygeon)", "residence saint- louis": "residence saint-louis", "st patrick's home": "st. patrick's home"}, inplace=True)
df_genLTC.info()
df_genLTC.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 30 columns):
# index                   625 non-null int64
# name                    625 non-null object
# address                 625 non-null object
# city_and_postal_code    625 non-null object
# LHIN                    625 non-null object
# licensee                625 non-null object
# management              71 non-null object
# home_type               624 non-null object
# beds                    625 non-null object
# short_stay              625 non-null object
# residents_council       625 non-null object
# family_council          625 non-null object
# accreditation           625 non-null object
# additional_info         4 non-null object
# city                    625 non-null object
# postal_code             625 non-null object
# number_of_beds          625 non-null int64
# total_inspections       625 non-null float64
# 5y_inspections          625 non-null float64
# 2y_inspections          625 non-null float64
# total_complaints        621 non-null float64
# 5y_complaints           588 non-null float64
# 2y_complaints           536 non-null float64
# total_critical          620 non-null float64
# 5y_critical             617 non-null float64
# 2y_critical             612 non-null float64
# total_withOrders        596 non-null float64
# 5y_withOrders           562 non-null float64
# 2y_withOrders           429 non-null float64
# cleaned_name            625 non-null object
# dtypes: float64(12), int64(2), object(16)
# memory usage: 146.6+ KB
#    index                                       name  \
# 0  0      AFTON PARK PLACE LONG TERM CARE COMMUNITY
# 1  1      ALBRIGHT GARDENS HOMES, INCORPORATED
# 2  2      ALEXANDER PLACE
# 3  4      ALGOMA MANOR NURSING HOME
# 4  5      ALGONQUIN NURSING HOME
#
#                                address city_and_postal_code  \
# 0  1200 Afton Drive                     Sarnia, N7S6L6
# 1  5050 Hillside Drive                  Beamsville, L0R1B2
# 2  329 Parkside Drive P. O.  Box 50     Waterdown, L0R2H0
# 3  145 Dawson Street                    Thessalon, P0R1L0
# 4  207 Turcotte Park Road P.O. Box 270  Mattawa, P0H1V0
#
#                                       LHIN  \
# 0  Erie St. Clair
# 1  Hamilton Niagara Haldimand Brant (Hnhb)
# 2  Hamilton Niagara Haldimand Brant (Hnhb)
# 3  North East
# 4  North East
#
#                                licensee                   management  \
# 0  S & R Nursing Homes Ltd.              NaN
# 1  Albright Gardens Homes, Incorporated  NaN
# 2  Waterdown Long Term Care Centre Inc.  NaN
# 3  Algoma Manor Nursing Home             NaN
# 4  Algonquin Nursing Home Of Mattawa     Hôpital De Mattawa Hospital
#
#     home_type                              beds short_stay residents_council  \
# 0  For-Profit  Home with approximately 128 beds  No         Yes
# 1  Non-Profit  Home with approximately 231 beds  No         Yes
# 2  For-Profit  Home with approximately 128 beds  Yes        Yes
# 3  NaN         Home with approximately 96 beds   Yes        Yes
# 4  Non-Profit  Home with approximately 73 beds   Yes        Yes
#
#   family_council accreditation additional_info        city postal_code  \
# 0  Yes            Yes           NaN             Sarnia       N7S6L6
# 1  Yes            No            NaN             Beamsville   L0R1B2
# 2  Yes            Yes           NaN             Waterdown    L0R2H0
# 3  Yes            Yes           NaN             Thessalon    P0R1L0
# 4  Yes            Yes           NaN             Mattawa      P0H1V0
#
#    number_of_beds  total_inspections  5y_inspections  2y_inspections  \
# 0  128             67.0               34.0            9.0
# 1  231             39.0               25.0            15.0
# 2  128             28.0               17.0            8.0
# 3  96              23.0               14.0            7.0
# 4  73              23.0               14.0            5.0
#
#    total_complaints  5y_complaints  2y_complaints  total_critical  \
# 0  29.0              15.0           3.0            28.0
# 1  18.0              10.0           6.0            12.0
# 2  11.0              6.0            3.0            8.0
# 3  7.0               5.0            2.0            3.0
# 4  3.0               1.0           NaN             11.0
#
#    5y_critical  2y_critical  total_withOrders  5y_withOrders  2y_withOrders  \
# 0  13.0         5.0          5.0               2.0           NaN
# 1  7.0          6.0          7.0               7.0            3.0
# 2  5.0          2.0          4.0               4.0            2.0
# 3  2.0          1.0          6.0               3.0            1.0
# 4  7.0          4.0          5.0               3.0           NaN
#
#                                 cleaned_name
# 0  afton park place long term care community
# 1  albright gardens homes, incorporated
# 2  alexander place
# 3  algoma manor nursing home
# 4  algonquin nursing home

# %%
# df_genLTC[df_genLTC['cleaned_name'].str.contains('meadows', regex=False, na=False)]

# %% [markdown]
# ## Merge general LTC and covid LTC data

# %%
# Import the covid LTC data
# df_covidLTC = pd.read_csv('merged_ltc.csv') # the orginal covid LTC data scraped in March
df_covidLTC = pd.read_csv('merged_ltc_secondScrape.csv')
df_covidLTC['cleaned_name'] = df_covidLTC['LTC Home'].str.lower()

df_covidLTC.info()
df_covidLTC.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 9 columns):
# Unnamed: 0                  293 non-null int64
# LTC Home                    293 non-null object
# City                        293 non-null object
# Beds                        293 non-null int64
# Confirmed Resident Cases    129 non-null object
# Resident Deaths             293 non-null object
# Confirmed Staff Cases       129 non-null object
# Status                      293 non-null object
# cleaned_name                293 non-null object
# dtypes: int64(2), object(7)
# memory usage: 20.7+ KB
#    Unnamed: 0                              LTC Home         City  Beds  \
# 0  0           Albright Gardens Homes, Incorporated  Beamsville   231
# 1  1           Alexander Place                       Waterdown    128
# 2  2           Almonte Country Haven                 Almonte      82
# 3  3           Altamont Care Community               Scarborough  159
# 4  4           Anson Place Care Centre               Hagersville  61
#
#   Confirmed Resident Cases Resident Deaths Confirmed Staff Cases  Status  \
# 0  <5                       0               0                     Active
# 1  <5                       0               0                     Active
# 2  0                        30              0                     Active
# 3  <5                       52              24                    Active
# 4  28                       23              29                    Active
#
#                            cleaned_name
# 0  albright gardens homes, incorporated
# 1  alexander place
# 2  almonte country haven
# 3  altamont care community
# 4  anson place care centre

# %%
# Check that homes from COVID LTC database are present in the general LTC database
a = set(df_genLTC['cleaned_name'])
b = set(df_covidLTC['cleaned_name'])

def returnNotMatches(a, b):
    return [[x for x in b if x not in a]]

returnNotMatches(a, b) # All homes present in the COVID database are present in the general database

# df_covidLTC['cleaned_name'].isin(df_genLTC['cleaned_name']).value_counts()
# Out:
# [[]]

# %%
# Merge the general LTC database with the COVID LTC database
df_LTC = pd.merge(left=df_genLTC, right=df_covidLTC, how='outer', left_on='cleaned_name', right_on='cleaned_name')

# %%
df_LTC.info()
df_LTC.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 625 entries, 0 to 624
# Data columns (total 38 columns):
# index                       625 non-null int64
# name                        625 non-null object
# address                     625 non-null object
# city_and_postal_code        625 non-null object
# LHIN                        625 non-null object
# licensee                    625 non-null object
# management                  71 non-null object
# home_type                   624 non-null object
# beds                        625 non-null object
# short_stay                  625 non-null object
# residents_council           625 non-null object
# family_council              625 non-null object
# accreditation               625 non-null object
# additional_info             4 non-null object
# city                        625 non-null object
# postal_code                 625 non-null object
# number_of_beds              625 non-null int64
# total_inspections           625 non-null float64
# 5y_inspections              625 non-null float64
# 2y_inspections              625 non-null float64
# total_complaints            621 non-null float64
# 5y_complaints               588 non-null float64
# 2y_complaints               536 non-null float64
# total_critical              620 non-null float64
# 5y_critical                 617 non-null float64
# 2y_critical                 612 non-null float64
# total_withOrders            596 non-null float64
# 5y_withOrders               562 non-null float64
# 2y_withOrders               429 non-null float64
# cleaned_name                625 non-null object
# Unnamed: 0                  293 non-null float64
# LTC Home                    293 non-null object
# City                        293 non-null object
# Beds                        293 non-null float64
# Confirmed Resident Cases    129 non-null object
# Resident Deaths             293 non-null object
# Confirmed Staff Cases       129 non-null object
# Status                      293 non-null object
# dtypes: float64(14), int64(2), object(22)
# memory usage: 190.4+ KB
#    index                                       name  \
# 0  0      AFTON PARK PLACE LONG TERM CARE COMMUNITY
# 1  1      ALBRIGHT GARDENS HOMES, INCORPORATED
# 2  2      ALEXANDER PLACE
# 3  4      ALGOMA MANOR NURSING HOME
# 4  5      ALGONQUIN NURSING HOME
#
#                                address city_and_postal_code  \
# 0  1200 Afton Drive                     Sarnia, N7S6L6
# 1  5050 Hillside Drive                  Beamsville, L0R1B2
# 2  329 Parkside Drive P. O.  Box 50     Waterdown, L0R2H0
# 3  145 Dawson Street                    Thessalon, P0R1L0
# 4  207 Turcotte Park Road P.O. Box 270  Mattawa, P0H1V0
#
#                                       LHIN  \
# 0  Erie St. Clair
# 1  Hamilton Niagara Haldimand Brant (Hnhb)
# 2  Hamilton Niagara Haldimand Brant (Hnhb)
# 3  North East
# 4  North East
#
#                                licensee                   management  \
# 0  S & R Nursing Homes Ltd.              NaN
# 1  Albright Gardens Homes, Incorporated  NaN
# 2  Waterdown Long Term Care Centre Inc.  NaN
# 3  Algoma Manor Nursing Home             NaN
# 4  Algonquin Nursing Home Of Mattawa     Hôpital De Mattawa Hospital
#
#     home_type                              beds short_stay residents_council  \
# 0  For-Profit  Home with approximately 128 beds  No         Yes
# 1  Non-Profit  Home with approximately 231 beds  No         Yes
# 2  For-Profit  Home with approximately 128 beds  Yes        Yes
# 3  NaN         Home with approximately 96 beds   Yes        Yes
# 4  Non-Profit  Home with approximately 73 beds   Yes        Yes
#
#   family_council accreditation additional_info        city postal_code  \
# 0  Yes            Yes           NaN             Sarnia       N7S6L6
# 1  Yes            No            NaN             Beamsville   L0R1B2
# 2  Yes            Yes           NaN             Waterdown    L0R2H0
# 3  Yes            Yes           NaN             Thessalon    P0R1L0
# 4  Yes            Yes           NaN             Mattawa      P0H1V0
#
#    number_of_beds  total_inspections  5y_inspections  2y_inspections  \
# 0  128             67.0               34.0            9.0
# 1  231             39.0               25.0            15.0
# 2  128             28.0               17.0            8.0
# 3  96              23.0               14.0            7.0
# 4  73              23.0               14.0            5.0
#
#    total_complaints  5y_complaints  2y_complaints  total_critical  \
# 0  29.0              15.0           3.0            28.0
# 1  18.0              10.0           6.0            12.0
# 2  11.0              6.0            3.0            8.0
# 3  7.0               5.0            2.0            3.0
# 4  3.0               1.0           NaN             11.0
#
#    5y_critical  2y_critical  total_withOrders  5y_withOrders  2y_withOrders  \
# 0  13.0         5.0          5.0               2.0           NaN
# 1  7.0          6.0          7.0               7.0            3.0
# 2  5.0          2.0          4.0               4.0            2.0
# 3  2.0          1.0          6.0               3.0            1.0
# 4  7.0          4.0          5.0               3.0           NaN
#
#                                 cleaned_name  Unnamed: 0  \
# 0  afton park place long term care community NaN
# 1  albright gardens homes, incorporated       0.0
# 2  alexander place                            1.0
# 3  algoma manor nursing home                 NaN
# 4  algonquin nursing home                    NaN
#
#                                LTC Home        City   Beds  \
# 0  NaN                                   NaN        NaN
# 1  Albright Gardens Homes, Incorporated  Beamsville  231.0
# 2  Alexander Place                       Waterdown   128.0
# 3  NaN                                   NaN        NaN
# 4  NaN                                   NaN        NaN
#
#   Confirmed Resident Cases Resident Deaths Confirmed Staff Cases  Status
# 0  NaN                      NaN             NaN                   NaN
# 1  <5                       0               0                     Active
# 2  <5                       0               0                     Active
# 3  NaN                      NaN             NaN                   NaN
# 4  NaN                      NaN             NaN                   NaN

# %%
# Check that the number of beds from the general LTC database agree with number of beds from the COVID LTC database
df_LTC_beds = df_LTC[df_LTC.Beds.notnull()]


# There are 23 homes where the number of beds in the 2 LTC databases do not agree
df_LTC_beds['bed_match'] = np.where((df_LTC_beds['number_of_beds'] == df_LTC_beds['Beds']), 'match', 'no_match')
df_LTC_beds['bed_match'].value_counts()
# Out:
# /Users/mds/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# match       270
# no_match    23
# Name: bed_match, dtype: int64

# %%
# Review homes where value for number of beds differ between the databases
df_LTC_beds = df_LTC_beds[df_LTC_beds['bed_match'] == 'no_match']
df_LTC_beds['diff_beds'] = df_LTC_beds['number_of_beds'] - df_LTC_beds['Beds']
df_LTC_beds[['cleaned_name', 'number_of_beds', 'Beds', 'diff_beds']]
# Out:
#                                        cleaned_name  number_of_beds   Beds  \
# 51   camilla care community                          237             236.0
# 76   cedarwood village                               91              90.0
# 79   centre d'accueil roger seguin                   110             113.0
# 89   chartwell pine grove long term care residence   101             96.0
# 95   chartwell westmount long term care residence    161             160.0
# 96   chartwell white eagle long term care residence  57              56.0
# 106  collingwood nursing home                        60              64.0
# 147  elmwood place                                   78              90.0
# 183  extendicare timmins                             121             180.0
# 226  glen hill strathaven                            199             210.0
# 231  golden years nursing home                       90              88.0
# 279  ioof seniors home                               188             182.0
# 286  kensington village                              126             78.0
# 321  manitoulin lodge                                61              62.0
# 357  mount hope centre for long term care            177             394.0
# 379  norview lodge                                   180             179.0
# 431  river glen haven nursing home                   120             119.0
# 475  st. patrick's home                              202             288.0
# 486  st. joseph's villa, dundas                      378             425.0
# 494  strathcona long term care                       88              87.0
# 508  temiskaming lodge                               82              83.0
# 563  tufford nursing home                            65              64.0
# 616  woodland villa                                  119             111.0
#
#      diff_beds
# 51   1.0
# 76   1.0
# 79  -3.0
# 89   5.0
# 95   1.0
# 96   1.0
# 106 -4.0
# 147 -12.0
# 183 -59.0
# 226 -11.0
# 231  2.0
# 279  6.0
# 286  48.0
# 321 -1.0
# 357 -217.0
# 379  1.0
# 431  1.0
# 475 -86.0
# 486 -47.0
# 494  1.0
# 508 -1.0
# 563  1.0
# 616  8.0

# %% [markdown]
# ## Manual review of some beds numbers discrepancies
# For kensington village, st. patrick's home and mount hope centre for long term care, websites support the COVID LTC values. Therefore where there is a discrepancy in the number of beds, we will take the number from the covid LTC database.

# %%
# Create a new column with number of beds as defined above
df_LTC['number_beds'] = np.nan
df_LTC['number_beds'] = np.where((df_LTC.Beds.isnull()), df_LTC['number_of_beds'], df_LTC['Beds'])
df_LTC.iloc[[620, 499]]
# Out:
#      index                           name              address  \
# 620  646    YEE HONG CENTRE - MISSISSAUGA  5510 Mavis Road
# 499  522    SUMMIT PLACE                   850-4Th Street East
#
#     city_and_postal_code                LHIN  \
# 620  Mississauga, L5V2X5  Mississauga Halton
# 499  Owen Sound, N4K6A3   South West
#
#                                licensee management   home_type  \
# 620  Yee Hong Centre For Geriatric Care  NaN        Non-Profit
# 499  Revera Long Term Care Inc.          NaN        For-Profit
#
#                                  beds short_stay residents_council  \
# 620  Home with approximately 200 beds  Yes        Yes
# 499  Home with approximately 119 beds  No         Yes
#
#     family_council accreditation additional_info         city postal_code  \
# 620  Yes            Yes           NaN             Mississauga   L5V2X5
# 499  Yes            Yes           NaN             Owen Sound    N4K6A3
#
#      number_of_beds  total_inspections  5y_inspections  2y_inspections  \
# 620  200             23.0               14.0            7.0
# 499  119             29.0               12.0            8.0
#
#      total_complaints  5y_complaints  2y_complaints  total_critical  \
# 620  10.0              4.0            3.0            7.0
# 499  10.0              3.0            2.0            11.0
#
#      5y_critical  2y_critical  total_withOrders  5y_withOrders  2y_withOrders  \
# 620  4.0          3.0          2.0               2.0            1.0
# 499  4.0          3.0          4.0               3.0            3.0
#
#                       cleaned_name  Unnamed: 0                       LTC Home  \
# 620  yee hong centre - mississauga  161.0       Yee Hong Centre - Mississauga
# 499  summit place                  NaN          NaN
#
#             City   Beds Confirmed Resident Cases Resident Deaths  \
# 620  Mississauga  200.0  NaN                      0
# 499  NaN         NaN     NaN                      NaN
#
#     Confirmed Staff Cases    Status  number_beds
# 620  NaN                   Inactive  200.0
# 499  NaN                   NaN       119.0

# %%
# Drop columns that are redundant/unnecessary
listofcols = ['index', 'city_and_postal_code', 'beds', 'number_of_beds', 'Unnamed: 0', 'LTC Home', 'City', 'Beds']
df_LTC.drop(listofcols, axis = 1, inplace = True)
df_LTC.head()
# Out:
#                                         name  \
# 0  AFTON PARK PLACE LONG TERM CARE COMMUNITY
# 1  ALBRIGHT GARDENS HOMES, INCORPORATED
# 2  ALEXANDER PLACE
# 3  ALGOMA MANOR NURSING HOME
# 4  ALGONQUIN NURSING HOME
#
#                                address  \
# 0  1200 Afton Drive
# 1  5050 Hillside Drive
# 2  329 Parkside Drive P. O.  Box 50
# 3  145 Dawson Street
# 4  207 Turcotte Park Road P.O. Box 270
#
#                                       LHIN  \
# 0  Erie St. Clair
# 1  Hamilton Niagara Haldimand Brant (Hnhb)
# 2  Hamilton Niagara Haldimand Brant (Hnhb)
# 3  North East
# 4  North East
#
#                                licensee                   management  \
# 0  S & R Nursing Homes Ltd.              NaN
# 1  Albright Gardens Homes, Incorporated  NaN
# 2  Waterdown Long Term Care Centre Inc.  NaN
# 3  Algoma Manor Nursing Home             NaN
# 4  Algonquin Nursing Home Of Mattawa     Hôpital De Mattawa Hospital
#
#     home_type short_stay residents_council family_council accreditation  \
# 0  For-Profit  No         Yes               Yes            Yes
# 1  Non-Profit  No         Yes               Yes            No
# 2  For-Profit  Yes        Yes               Yes            Yes
# 3  NaN         Yes        Yes               Yes            Yes
# 4  Non-Profit  Yes        Yes               Yes            Yes
#
#   additional_info        city postal_code  total_inspections  5y_inspections  \
# 0  NaN             Sarnia       N7S6L6     67.0               34.0
# 1  NaN             Beamsville   L0R1B2     39.0               25.0
# 2  NaN             Waterdown    L0R2H0     28.0               17.0
# 3  NaN             Thessalon    P0R1L0     23.0               14.0
# 4  NaN             Mattawa      P0H1V0     23.0               14.0
#
#    2y_inspections  total_complaints  5y_complaints  2y_complaints  \
# 0  9.0             29.0              15.0           3.0
# 1  15.0            18.0              10.0           6.0
# 2  8.0             11.0              6.0            3.0
# 3  7.0             7.0               5.0            2.0
# 4  5.0             3.0               1.0           NaN
#
#    total_critical  5y_critical  2y_critical  total_withOrders  5y_withOrders  \
# 0  28.0            13.0         5.0          5.0               2.0
# 1  12.0            7.0          6.0          7.0               7.0
# 2  8.0             5.0          2.0          4.0               4.0
# 3  3.0             2.0          1.0          6.0               3.0
# 4  11.0            7.0          4.0          5.0               3.0
#
#    2y_withOrders                               cleaned_name  \
# 0 NaN             afton park place long term care community
# 1  3.0            albright gardens homes, incorporated
# 2  2.0            alexander place
# 3  1.0            algoma manor nursing home
# 4 NaN             algonquin nursing home
#
#   Confirmed Resident Cases Resident Deaths Confirmed Staff Cases  Status  \
# 0  NaN                      NaN             NaN                   NaN
# 1  <5                       0               0                     Active
# 2  <5                       0               0                     Active
# 3  NaN                      NaN             NaN                   NaN
# 4  NaN                      NaN             NaN                   NaN
#
#    number_beds
# 0  128.0
# 1  231.0
# 2  128.0
# 3  96.0
# 4  73.0

# %%
df_LTC.info()
# df_LTC.to_csv(r'merge_genltc_covidltc_FINAL.csv', index = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 625 entries, 0 to 624
# Data columns (total 31 columns):
# name                        625 non-null object
# address                     625 non-null object
# LHIN                        625 non-null object
# licensee                    625 non-null object
# management                  71 non-null object
# home_type                   624 non-null object
# short_stay                  625 non-null object
# residents_council           625 non-null object
# family_council              625 non-null object
# accreditation               625 non-null object
# additional_info             4 non-null object
# city                        625 non-null object
# postal_code                 625 non-null object
# total_inspections           625 non-null float64
# 5y_inspections              625 non-null float64
# 2y_inspections              625 non-null float64
# total_complaints            621 non-null float64
# 5y_complaints               588 non-null float64
# 2y_complaints               536 non-null float64
# total_critical              620 non-null float64
# 5y_critical                 617 non-null float64
# 2y_critical                 612 non-null float64
# total_withOrders            596 non-null float64
# 5y_withOrders               562 non-null float64
# 2y_withOrders               429 non-null float64
# cleaned_name                625 non-null object
# Confirmed Resident Cases    129 non-null object
# Resident Deaths             293 non-null object
# Confirmed Staff Cases       129 non-null object
# Status                      293 non-null object
# number_beds                 625 non-null float64
# dtypes: float64(13), object(18)
# memory usage: 156.2+ KB

# %% [markdown]
# ## Import and prep ODHF data
# - We are merging with the ODHF data to obtain the geodata for the LTC homes

# %%
# Import ODHF data for Ontario
odhf = pd.read_csv(r'ohdf_v1_ontario.csv')

odhf.info()
odhf.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3733 entries, 0 to 3732
# Data columns (total 17 columns):
# index                        3733 non-null int64
# facility_name                3733 non-null object
# source_facility_type         3705 non-null object
# odhf_facility_type           3728 non-null object
# provider                     3733 non-null object
# unit                         0 non-null float64
# street_no                    3122 non-null object
# street_name                  3154 non-null object
# postal_code                  3726 non-null object
# city                         3724 non-null object
# province                     3733 non-null object
# source_format_str_address    271 non-null object
# CSDname                      3540 non-null object
# CSDuid                       3151 non-null float64
# Pruid                        3733 non-null int64
# latitude                     3159 non-null float64
# longitude                    3159 non-null float64
# dtypes: float64(4), int64(2), object(11)
# memory usage: 495.9+ KB
#    index  \
# 0  2401
# 1  2402
# 2  2403
# 3  2404
# 4  2405
#
#                                                               facility_name  \
# 0  (georgian, trillium & sunset manors) corporation of the county of simcoe
# 1  147 elder street inc.
# 2  2 spirited people of the 1st nations
# 3  3 c's reintroduction centre, the
# 4  RÈsidence St. FranÁois
#
#                        source_facility_type  \
# 0  community support service
# 1  retirement home
# 2  community support service
# 3  mental health and addiction organization
# 4  retirement home
#
#                         odhf_facility_type             provider  unit  \
# 0  Ambulatory health care services          Province of Ontario NaN
# 1  Nursing and residential care facilities  Province of Ontario NaN
# 2  Ambulatory health care services          Province of Ontario NaN
# 3  Nursing and residential care facilities  Province of Ontario NaN
# 4  Nursing and residential care facilities  Province of Ontario NaN
#
#   street_no     street_name postal_code         city province  \
# 0  1110      highway 26      L0L1X0      midhurst     on
# 1  147       elder street    M3H5G9      toronto      on
# 2  145       front street e  M5A1E3      toronto      on
# 3  226       dog lake road   P7G2G2      thunder bay  on
# 4  790       rue principale  K0A1M0      casselman    on
#
#   source_format_str_address      CSDname     CSDuid  Pruid   latitude  \
# 0  NaN                       Springwater  3543009.0  35     44.444915
# 1  NaN                       Toronto      3520005.0  35     43.762894
# 2  NaN                       Toronto      3520005.0  35     43.649821
# 3  NaN                       Thunder Bay  3558004.0  35     48.486760
# 4  NaN                       Casselman    3502044.0  35     45.316392
#
#    longitude
# 0 -79.744846
# 1 -79.454109
# 2 -79.369350
# 3 -89.321521
# 4 -75.090252

# %%
# Clean facility name
import unicodedata
odhf['cleaned_name'] = odhf['facility_name'].str.lower().apply(lambda val: unicodedata.normalize('NFKD', val).encode('ascii', 'ignore').decode())
odhf.head()
# Out:
#    index  \
# 0  2401
# 1  2402
# 2  2403
# 3  2404
# 4  2405
#
#                                                               facility_name  \
# 0  (georgian, trillium & sunset manors) corporation of the county of simcoe
# 1  147 elder street inc.
# 2  2 spirited people of the 1st nations
# 3  3 c's reintroduction centre, the
# 4  RÈsidence St. FranÁois
#
#                        source_facility_type  \
# 0  community support service
# 1  retirement home
# 2  community support service
# 3  mental health and addiction organization
# 4  retirement home
#
#                         odhf_facility_type             provider  unit  \
# 0  Ambulatory health care services          Province of Ontario NaN
# 1  Nursing and residential care facilities  Province of Ontario NaN
# 2  Ambulatory health care services          Province of Ontario NaN
# 3  Nursing and residential care facilities  Province of Ontario NaN
# 4  Nursing and residential care facilities  Province of Ontario NaN
#
#   street_no     street_name postal_code         city province  \
# 0  1110      highway 26      L0L1X0      midhurst     on
# 1  147       elder street    M3H5G9      toronto      on
# 2  145       front street e  M5A1E3      toronto      on
# 3  226       dog lake road   P7G2G2      thunder bay  on
# 4  790       rue principale  K0A1M0      casselman    on
#
#   source_format_str_address      CSDname     CSDuid  Pruid   latitude  \
# 0  NaN                       Springwater  3543009.0  35     44.444915
# 1  NaN                       Toronto      3520005.0  35     43.762894
# 2  NaN                       Toronto      3520005.0  35     43.649821
# 3  NaN                       Thunder Bay  3558004.0  35     48.486760
# 4  NaN                       Casselman    3502044.0  35     45.316392
#
#    longitude  \
# 0 -79.744846
# 1 -79.454109
# 2 -79.369350
# 3 -89.321521
# 4 -75.090252
#
#                                                                cleaned_name
# 0  (georgian, trillium & sunset manors) corporation of the county of simcoe
# 1  147 elder street inc.
# 2  2 spirited people of the 1st nations
# 3  3 c's reintroduction centre, the
# 4  residence st. franaois

# %%
# odhf[odhf['cleaned_name'].str.contains('meadows', regex=False, na=False)]

# %% [markdown]
# ## List of homes in the LTC database that are not listed in the ODHF

# %%
a = set(odhf['cleaned_name'])
b = set(df_LTC['cleaned_name'])

def returnNotMatches(a, b):
    return [x for x in b if x not in a]

missing_odhf = returnNotMatches(a, b)

# %%
len(missing_odhf)
# Out:
# 19

# %%
missing_odhf.sort()
missing_odhf
# Out:
# ['albright gardens homes, incorporated',
#  'bella senior care residences inc.',
#  'bon air long term care residence',
#  'caressant care cobden',
#  'caressant care harriston',
#  'champlain long term care residence',
#  'heartwood (fka versa-care cornwall)',
#  'lancaster long term care residence',
#  'niagara long term care residence',
#  'north renfrew long-term care services',
#  'north shore health network – eldcap unit',
#  'north shore health network – ltc unit',
#  'santé manitouwadge health',
#  "st. joseph's health centre, guelph",
#  "st. joseph's villa, dundas",
#  'strathcona long term care',
#  'the meadows',
#  'william a. "bill" george extended care facility',
#  'élisabeth-bruyère residence']

# %% [markdown]
# ## Replace cleaned names in the LTC and ODHF df

# %%
df_LTC['cleaned_name'] = df_LTC['cleaned_name'].replace({
    'albright gardens homes, incorporated' : 'albright gardens',
    'bella senior care residences inc.':'bella senior care residences',
    'bon air long term care residence':'chartwell bon air long term care residence',
    'caressant care cobden':'caressant care - cobden',
    'caressant care harriston':'caressant care - harriston',
    'champlain long term care residence':'chartwell champlain long term care residence',
    'heartwood (fka versa-care cornwall)':'heartwood',
    'lancaster long term care residence':'chartwell lancaster long term care residence',
    'niagara long term care residence':'chartwell niagara long term care residence',
    'north renfrew long-term care services':'north renfrew long-term care services inc.',
    'north shore health network – eldcap unit':'north shore health network - eldcap unit' ,
    'north shore health network – ltc unit' : 'north shore health network - ltc unit',
    'santé manitouwadge health':'sante manitouwadge health',
    'st. joseph\'s health centre, guelph':'st. joseph\'s health centre - guelph',
    'st. joseph\'s villa, dundas' : "st. joseph's villa (dundas)",
# strathcona long term care, MISSING SEE NOTE
    'the meadows':'revera inc. o the meadows long term care centre',
    'william a. "bill" george extended care facility': 'william a. \'bill\' george extended care facility',
    'élisabeth-bruyère residence':'elisabeth-bruyere residence'
})

odhf['cleaned_name'] = odhf['cleaned_name'].replace({'lisabeth-bruyre residence': 'elisabeth-bruyere residence',
                                             'rsidence saint-louis' : 'residence saint-louis'})

# %%
a = set(odhf['cleaned_name'])
b = set(df_LTC['cleaned_name'])

def returnNotMatches(a, b):
    return [x for x in b if x not in a]

missing_odhf_names = returnNotMatches(a, b)
print(len(missing_odhf_names))

missing_odhf_names.sort()
missing_odhf_names
# Out:
# 1
# ['strathcona long term care']

# %% [markdown]
# ## Manual review of discrepancy between LTC data and ODHF
# ### Missing from ODHF
# 1. Strathcona Long Term Care, https://svch.ca/long-term-care/strathcona/location/, has replaced saugeen valley nursing center in ODHF which is at the same address, https://svch.ca/saugeen-valley-nursing-centre-announces-plan-to-redevelop-87-bed-facility-in-mount-forest/#.Xr2rvRNKjfY
#
# ### Other notes:
# - sante manitouwadge health: called and this is part of the hospital with 9 LTC beds
#
# ### We will change Saugeen Valley to Strathcona in ODHF before merging the LTC data with ODHF

# %%
# Replace saugeen with strathcona in ODHF
odhf['cleaned_name'] = odhf['cleaned_name'].replace({'saugeen valley nursing center': 'strathcona long term care'})

odhf[odhf['cleaned_name'].str.contains('strathcona', regex=False, na=False)]
# odhf.iloc[2721]
# Out:
#       index                  facility_name source_facility_type  \
# 2721  5122   saugeen valley nursing center  long-term care home
#
#                            odhf_facility_type             provider  unit  \
# 2721  Nursing and residential care facilities  Province of Ontario NaN
#
#      street_no    street_name postal_code          city province  \
# 2721  465       dublin street  N0G2L3      mount forest  on
#
#      source_format_str_address           CSDname     CSDuid  Pruid   latitude  \
# 2721  NaN                       Wellington North  3523050.0  35     43.975099
#
#       longitude               cleaned_name
# 2721 -80.73934   strathcona long term care

# %% [markdown]
# ## Merge LTC data with ODHF

# %%
df_LTC_odhf = pd.merge(left=df_LTC, right=odhf, 
                  how='left', left_on='cleaned_name', 
                  right_on='cleaned_name')
df_LTC_odhf.info()
df_LTC_odhf.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 625 entries, 0 to 624
# Data columns (total 48 columns):
# name                         625 non-null object
# address                      625 non-null object
# LHIN                         625 non-null object
# licensee                     625 non-null object
# management                   71 non-null object
# home_type                    624 non-null object
# short_stay                   625 non-null object
# residents_council            625 non-null object
# family_council               625 non-null object
# accreditation                625 non-null object
# additional_info              4 non-null object
# city_x                       625 non-null object
# postal_code_x                625 non-null object
# total_inspections            625 non-null float64
# 5y_inspections               625 non-null float64
# 2y_inspections               625 non-null float64
# total_complaints             621 non-null float64
# 5y_complaints                588 non-null float64
# 2y_complaints                536 non-null float64
# total_critical               620 non-null float64
# 5y_critical                  617 non-null float64
# 2y_critical                  612 non-null float64
# total_withOrders             596 non-null float64
# 5y_withOrders                562 non-null float64
# 2y_withOrders                429 non-null float64
# cleaned_name                 625 non-null object
# Confirmed Resident Cases     129 non-null object
# Resident Deaths              293 non-null object
# Confirmed Staff Cases        129 non-null object
# Status                       293 non-null object
# number_beds                  625 non-null float64
# index                        625 non-null int64
# facility_name                625 non-null object
# source_facility_type         625 non-null object
# odhf_facility_type           625 non-null object
# provider                     625 non-null object
# unit                         0 non-null float64
# street_no                    622 non-null object
# street_name                  624 non-null object
# postal_code_y                625 non-null object
# city_y                       622 non-null object
# province                     625 non-null object
# source_format_str_address    9 non-null object
# CSDname                      624 non-null object
# CSDuid                       623 non-null float64
# Pruid                        625 non-null int64
# latitude                     624 non-null float64
# longitude                    624 non-null float64
# dtypes: float64(17), int64(2), object(29)
# memory usage: 239.3+ KB
#                                         name  \
# 0  AFTON PARK PLACE LONG TERM CARE COMMUNITY
# 1  ALBRIGHT GARDENS HOMES, INCORPORATED
# 2  ALEXANDER PLACE
# 3  ALGOMA MANOR NURSING HOME
# 4  ALGONQUIN NURSING HOME
#
#                                address  \
# 0  1200 Afton Drive
# 1  5050 Hillside Drive
# 2  329 Parkside Drive P. O.  Box 50
# 3  145 Dawson Street
# 4  207 Turcotte Park Road P.O. Box 270
#
#                                       LHIN  \
# 0  Erie St. Clair
# 1  Hamilton Niagara Haldimand Brant (Hnhb)
# 2  Hamilton Niagara Haldimand Brant (Hnhb)
# 3  North East
# 4  North East
#
#                                licensee                   management  \
# 0  S & R Nursing Homes Ltd.              NaN
# 1  Albright Gardens Homes, Incorporated  NaN
# 2  Waterdown Long Term Care Centre Inc.  NaN
# 3  Algoma Manor Nursing Home             NaN
# 4  Algonquin Nursing Home Of Mattawa     Hôpital De Mattawa Hospital
#
#     home_type short_stay residents_council family_council accreditation  \
# 0  For-Profit  No         Yes               Yes            Yes
# 1  Non-Profit  No         Yes               Yes            No
# 2  For-Profit  Yes        Yes               Yes            Yes
# 3  NaN         Yes        Yes               Yes            Yes
# 4  Non-Profit  Yes        Yes               Yes            Yes
#
#   additional_info      city_x postal_code_x  total_inspections  \
# 0  NaN             Sarnia       N7S6L6       67.0
# 1  NaN             Beamsville   L0R1B2       39.0
# 2  NaN             Waterdown    L0R2H0       28.0
# 3  NaN             Thessalon    P0R1L0       23.0
# 4  NaN             Mattawa      P0H1V0       23.0
#
#    5y_inspections  2y_inspections  total_complaints  5y_complaints  \
# 0  34.0            9.0             29.0              15.0
# 1  25.0            15.0            18.0              10.0
# 2  17.0            8.0             11.0              6.0
# 3  14.0            7.0             7.0               5.0
# 4  14.0            5.0             3.0               1.0
#
#    2y_complaints  total_critical  5y_critical  2y_critical  total_withOrders  \
# 0  3.0            28.0            13.0         5.0          5.0
# 1  6.0            12.0            7.0          6.0          7.0
# 2  3.0            8.0             5.0          2.0          4.0
# 3  2.0            3.0             2.0          1.0          6.0
# 4 NaN             11.0            7.0          4.0          5.0
#
#    5y_withOrders  2y_withOrders                               cleaned_name  \
# 0  2.0           NaN             afton park place long term care community
# 1  7.0            3.0            albright gardens
# 2  4.0            2.0            alexander place
# 3  3.0            1.0            algoma manor nursing home
# 4  3.0           NaN             algonquin nursing home
#
#   Confirmed Resident Cases Resident Deaths Confirmed Staff Cases  Status  \
# 0  NaN                      NaN             NaN                   NaN
# 1  <5                       0               0                     Active
# 2  <5                       0               0                     Active
# 3  NaN                      NaN             NaN                   NaN
# 4  NaN                      NaN             NaN                   NaN
#
#    number_beds  index                              facility_name  \
# 0  128.0        2435   afton park place long term care community
# 1  231.0        2439   albright gardens
# 2  128.0        2442   alexander place
# 3  96.0         2449   algoma manor nursing home
# 4  73.0         2456   algonquin nursing home
#
#   source_facility_type                       odhf_facility_type  \
# 0  long-term care home  Nursing and residential care facilities
# 1  long-term care home  Nursing and residential care facilities
# 2  long-term care home  Nursing and residential care facilities
# 3  long-term care home  Nursing and residential care facilities
# 4  long-term care home  Nursing and residential care facilities
#
#               provider  unit street_no     street_name postal_code_y  \
# 0  Province of Ontario NaN    1200      afton drive     N7S6L6
# 1  Province of Ontario NaN    5050      hillside drive  L0R1B2
# 2  Province of Ontario NaN    329       parkside drive  L0R2H0
# 3  Province of Ontario NaN    145       dawson street   P0R1L0
# 4  Province of Ontario NaN    231       10 street       P0H1V0
#
#       city_y province source_format_str_address    CSDname     CSDuid  Pruid  \
# 0  sarnia     on       NaN                       Sarnia     3538030.0  35
# 1  lincoln    on       NaN                       Lincoln    3526057.0  35
# 2  hamilton   on       NaN                       Hamilton   3525005.0  35
# 3  thessalon  on       NaN                       Thessalon  3557028.0  35
# 4  mattawa    on       NaN                       Mattawa    3548021.0  35
#
#     latitude  longitude
# 0  42.976325 -82.361444
# 1  43.151877 -79.476598
# 2  43.342345 -79.900820
# 3  46.263462 -83.563249
# 4  46.313493 -78.719841

# %%
df_LTC_odhf.head()
# Out:
#                                         name  \
# 0  AFTON PARK PLACE LONG TERM CARE COMMUNITY
# 1  ALBRIGHT GARDENS HOMES, INCORPORATED
# 2  ALEXANDER PLACE
# 3  ALGOMA MANOR NURSING HOME
# 4  ALGONQUIN NURSING HOME
#
#                                address  \
# 0  1200 Afton Drive
# 1  5050 Hillside Drive
# 2  329 Parkside Drive P. O.  Box 50
# 3  145 Dawson Street
# 4  207 Turcotte Park Road P.O. Box 270
#
#                                       LHIN  \
# 0  Erie St. Clair
# 1  Hamilton Niagara Haldimand Brant (Hnhb)
# 2  Hamilton Niagara Haldimand Brant (Hnhb)
# 3  North East
# 4  North East
#
#                                licensee                   management  \
# 0  S & R Nursing Homes Ltd.              NaN
# 1  Albright Gardens Homes, Incorporated  NaN
# 2  Waterdown Long Term Care Centre Inc.  NaN
# 3  Algoma Manor Nursing Home             NaN
# 4  Algonquin Nursing Home Of Mattawa     Hôpital De Mattawa Hospital
#
#     home_type short_stay residents_council family_council accreditation  \
# 0  For-Profit  No         Yes               Yes            Yes
# 1  Non-Profit  No         Yes               Yes            No
# 2  For-Profit  Yes        Yes               Yes            Yes
# 3  NaN         Yes        Yes               Yes            Yes
# 4  Non-Profit  Yes        Yes               Yes            Yes
#
#   additional_info      city_x postal_code_x  total_inspections  \
# 0  NaN             Sarnia       N7S6L6       67.0
# 1  NaN             Beamsville   L0R1B2       39.0
# 2  NaN             Waterdown    L0R2H0       28.0
# 3  NaN             Thessalon    P0R1L0       23.0
# 4  NaN             Mattawa      P0H1V0       23.0
#
#    5y_inspections  2y_inspections  total_complaints  5y_complaints  \
# 0  34.0            9.0             29.0              15.0
# 1  25.0            15.0            18.0              10.0
# 2  17.0            8.0             11.0              6.0
# 3  14.0            7.0             7.0               5.0
# 4  14.0            5.0             3.0               1.0
#
#    2y_complaints  total_critical  5y_critical  2y_critical  total_withOrders  \
# 0  3.0            28.0            13.0         5.0          5.0
# 1  6.0            12.0            7.0          6.0          7.0
# 2  3.0            8.0             5.0          2.0          4.0
# 3  2.0            3.0             2.0          1.0          6.0
# 4 NaN             11.0            7.0          4.0          5.0
#
#    5y_withOrders  2y_withOrders                               cleaned_name  \
# 0  2.0           NaN             afton park place long term care community
# 1  7.0            3.0            albright gardens
# 2  4.0            2.0            alexander place
# 3  3.0            1.0            algoma manor nursing home
# 4  3.0           NaN             algonquin nursing home
#
#   Confirmed Resident Cases Resident Deaths Confirmed Staff Cases  Status  \
# 0  NaN                      NaN             NaN                   NaN
# 1  <5                       0               0                     Active
# 2  <5                       0               0                     Active
# 3  NaN                      NaN             NaN                   NaN
# 4  NaN                      NaN             NaN                   NaN
#
#    number_beds  index                              facility_name  \
# 0  128.0        2435   afton park place long term care community
# 1  231.0        2439   albright gardens
# 2  128.0        2442   alexander place
# 3  96.0         2449   algoma manor nursing home
# 4  73.0         2456   algonquin nursing home
#
#   source_facility_type                       odhf_facility_type  \
# 0  long-term care home  Nursing and residential care facilities
# 1  long-term care home  Nursing and residential care facilities
# 2  long-term care home  Nursing and residential care facilities
# 3  long-term care home  Nursing and residential care facilities
# 4  long-term care home  Nursing and residential care facilities
#
#               provider  unit street_no     street_name postal_code_y  \
# 0  Province of Ontario NaN    1200      afton drive     N7S6L6
# 1  Province of Ontario NaN    5050      hillside drive  L0R1B2
# 2  Province of Ontario NaN    329       parkside drive  L0R2H0
# 3  Province of Ontario NaN    145       dawson street   P0R1L0
# 4  Province of Ontario NaN    231       10 street       P0H1V0
#
#       city_y province source_format_str_address    CSDname     CSDuid  Pruid  \
# 0  sarnia     on       NaN                       Sarnia     3538030.0  35
# 1  lincoln    on       NaN                       Lincoln    3526057.0  35
# 2  hamilton   on       NaN                       Hamilton   3525005.0  35
# 3  thessalon  on       NaN                       Thessalon  3557028.0  35
# 4  mattawa    on       NaN                       Mattawa    3548021.0  35
#
#     latitude  longitude
# 0  42.976325 -82.361444
# 1  43.151877 -79.476598
# 2  43.342345 -79.900820
# 3  46.263462 -83.563249
# 4  46.313493 -78.719841

# %%
list_col = ['licensee', 'management', 'index', 'facility_name', 'source_facility_type', 
            'odhf_facility_type', 'provider', 'unit', 'street_no', 'street_name',
            'postal_code_y','city_y', 'province', 'source_format_str_address', 'Pruid']
df_LTC_odhf = df_LTC_odhf.drop(list_col, axis = 1)
df_LTC_odhf = df_LTC_odhf.rename(columns = {'city_x':'city', 'postal_code_x': 'postal_code'})
df_LTC_odhf.head()
df_LTC_odhf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 625 entries, 0 to 624
# Data columns (total 33 columns):
# name                        625 non-null object
# address                     625 non-null object
# LHIN                        625 non-null object
# home_type                   624 non-null object
# short_stay                  625 non-null object
# residents_council           625 non-null object
# family_council              625 non-null object
# accreditation               625 non-null object
# additional_info             4 non-null object
# city                        625 non-null object
# postal_code                 625 non-null object
# total_inspections           625 non-null float64
# 5y_inspections              625 non-null float64
# 2y_inspections              625 non-null float64
# total_complaints            621 non-null float64
# 5y_complaints               588 non-null float64
# 2y_complaints               536 non-null float64
# total_critical              620 non-null float64
# 5y_critical                 617 non-null float64
# 2y_critical                 612 non-null float64
# total_withOrders            596 non-null float64
# 5y_withOrders               562 non-null float64
# 2y_withOrders               429 non-null float64
# cleaned_name                625 non-null object
# Confirmed Resident Cases    129 non-null object
# Resident Deaths             293 non-null object
# Confirmed Staff Cases       129 non-null object
# Status                      293 non-null object
# number_beds                 625 non-null float64
# CSDname                     624 non-null object
# CSDuid                      623 non-null float64
# latitude                    624 non-null float64
# longitude                   624 non-null float64
# dtypes: float64(16), object(17)
# memory usage: 166.0+ KB

# %%
# df_LTC_odhf['home_type'].value_counts()
# df_LTC_odhf['family_council'].value_counts()
# df_LTC_odhf['accreditation'].value_counts()
# df_LTC_odhf.cleaned_name.str.contains("hospital", na=False).value_counts()
# df_LTC_odhf[df_LTC_odhf['cleaned_name'].str.contains('hospital', regex=False, na=False)]

# %% [markdown]
# ## Review LTC homes with missing values

# %%
# Assess home with missing home_type
df_LTC_odhf[df_LTC_odhf['home_type'].isnull()] # algoma manor nursing home
# df_trim['home type'].value_counts()
# Out:
#                         name            address        LHIN home_type  \
# 3  ALGOMA MANOR NURSING HOME  145 Dawson Street  North East  NaN
#
#   short_stay residents_council family_council accreditation additional_info  \
# 3  Yes        Yes               Yes            Yes           NaN
#
#         city postal_code  total_inspections  5y_inspections  2y_inspections  \
# 3  Thessalon   P0R1L0     23.0               14.0            7.0
#
#    total_complaints  5y_complaints  2y_complaints  total_critical  \
# 3  7.0               5.0            2.0            3.0
#
#    5y_critical  2y_critical  total_withOrders  5y_withOrders  2y_withOrders  \
# 3  2.0          1.0          6.0               3.0            1.0
#
#                 cleaned_name Confirmed Resident Cases Resident Deaths  \
# 3  algoma manor nursing home  NaN                      NaN
#
#   Confirmed Staff Cases Status  number_beds    CSDname     CSDuid   latitude  \
# 3  NaN                   NaN    96.0         Thessalon  3557028.0  46.263462
#
#    longitude
# 3 -83.563249

# %%
# Fill in some of the missing values for lennox and addington county general hospital manually
# This home was removed from the general LTC database previously
# df_trim.at[311,'LHIN'] = 'South East'
# df_trim.at[311,'home type'] = 'Non-Profit'
# df_trim.at[311,'short stay'] = 'Yes'
# df_trim.at[311,'number_beds'] = '22'

# Fill in missing home type value for algoma manor
df_LTC_odhf.at[3, 'home_type'] = 'Non-Profit'

# %%
df_LTC_odhf.loc[df_LTC_odhf['cleaned_name'] == 'algoma manor nursing home']
# Out:
#                         name            address        LHIN   home_type  \
# 3  ALGOMA MANOR NURSING HOME  145 Dawson Street  North East  Non-Profit
#
#   short_stay residents_council family_council accreditation additional_info  \
# 3  Yes        Yes               Yes            Yes           NaN
#
#         city postal_code  total_inspections  5y_inspections  2y_inspections  \
# 3  Thessalon   P0R1L0     23.0               14.0            7.0
#
#    total_complaints  5y_complaints  2y_complaints  total_critical  \
# 3  7.0               5.0            2.0            3.0
#
#    5y_critical  2y_critical  total_withOrders  5y_withOrders  2y_withOrders  \
# 3  2.0          1.0          6.0               3.0            1.0
#
#                 cleaned_name Confirmed Resident Cases Resident Deaths  \
# 3  algoma manor nursing home  NaN                      NaN
#
#   Confirmed Staff Cases Status  number_beds    CSDname     CSDuid   latitude  \
# 3  NaN                   NaN    96.0         Thessalon  3557028.0  46.263462
#
#    longitude
# 3 -83.563249

# %% [markdown]
# Algoma manor nursing home: missing home type, https://www.northeasthealthline.ca/displayservice.aspx?id=90025

# %%
df_LTC_odhf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 625 entries, 0 to 624
# Data columns (total 33 columns):
# name                        625 non-null object
# address                     625 non-null object
# LHIN                        625 non-null object
# home_type                   625 non-null object
# short_stay                  625 non-null object
# residents_council           625 non-null object
# family_council              625 non-null object
# accreditation               625 non-null object
# additional_info             4 non-null object
# city                        625 non-null object
# postal_code                 625 non-null object
# total_inspections           625 non-null float64
# 5y_inspections              625 non-null float64
# 2y_inspections              625 non-null float64
# total_complaints            621 non-null float64
# 5y_complaints               588 non-null float64
# 2y_complaints               536 non-null float64
# total_critical              620 non-null float64
# 5y_critical                 617 non-null float64
# 2y_critical                 612 non-null float64
# total_withOrders            596 non-null float64
# 5y_withOrders               562 non-null float64
# 2y_withOrders               429 non-null float64
# cleaned_name                625 non-null object
# Confirmed Resident Cases    129 non-null object
# Resident Deaths             293 non-null object
# Confirmed Staff Cases       129 non-null object
# Status                      293 non-null object
# number_beds                 625 non-null float64
# CSDname                     624 non-null object
# CSDuid                      623 non-null float64
# latitude                    624 non-null float64
# longitude                   624 non-null float64
# dtypes: float64(16), object(17)
# memory usage: 186.0+ KB

# %% [markdown]
# ## Export merged file

# %%
df_LTC_odhf.to_csv(r'merged_LTC_odhf.csv', index = False)
