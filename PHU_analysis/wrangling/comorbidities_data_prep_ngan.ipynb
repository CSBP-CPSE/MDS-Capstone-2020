# %%
import pandas as pd

pd.set_option(display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %%
# Import the comorbidity data
df = pd.read_csv('comorbidity_data.csv')

# Subset the DGUID so that it matches
df['ts_guid'] = df.DGUID.str[5:]
df.info()

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 897876 entries, 0 to 897875
# Data columns (total 19 columns):
# REF_DATE           897876 non-null object
# GEO                897876 non-null object
# DGUID              897876 non-null object
# Age group          897876 non-null object
# Sex                897876 non-null object
# Indicators         897876 non-null object
# Characteristics    897876 non-null object
# UOM                897876 non-null object
# UOM_ID             897876 non-null int64
# SCALAR_FACTOR      897876 non-null object
# SCALAR_ID          897876 non-null int64
# VECTOR             897876 non-null object
# COORDINATE         897876 non-null object
# VALUE              639334 non-null float64
# STATUS             481259 non-null object
# SYMBOL             0 non-null float64
# TERMINATED         0 non-null float64
# DECIMALS           897876 non-null int64
# ts_guid            897876 non-null object
# dtypes: float64(3), int64(3), object(13)
# memory usage: 130.2+ MB
#     REF_DATE     GEO           DGUID                 Age group         Sex  \
# 0  2015/2016  Canada  2016A000011124  Total, 12 years and over  Both sexes
# 1  2015/2016  Canada  2016A000011124  Total, 12 years and over  Both sexes
# 2  2015/2016  Canada  2016A000011124  Total, 12 years and over  Both sexes
# 3  2015/2016  Canada  2016A000011124  Total, 12 years and over  Both sexes
# 4  2015/2016  Canada  2016A000011124  Total, 12 years and over  Both sexes
#
#                                  Indicators  \
# 0  Perceived health, very good or excellent
# 1  Perceived health, very good or excellent
# 2  Perceived health, very good or excellent
# 3  Perceived health, very good or excellent
# 4  Perceived health, very good or excellent
#
#                                    Characteristics      UOM  UOM_ID  \
# 0  Number of persons                                Number   223
# 1  Low 95% confidence interval, number of persons   Number   223
# 2  High 95% confidence interval, number of persons  Number   223
# 3  Percent                                          Percent  239
# 4  Low 95% confidence interval, percent             Percent  239
#
#   SCALAR_FACTOR  SCALAR_ID      VECTOR COORDINATE       VALUE STATUS  SYMBOL  \
# 0  units         0          v115439164  1.1.1.1.1  18787800.0  NaN   NaN
# 1  units         0          v115439165  1.1.1.1.2  18637400.0  NaN   NaN
# 2  units         0          v115439166  1.1.1.1.3  18928800.0  NaN   NaN
# 3  units         0          v115439167  1.1.1.1.4  61.5        NaN   NaN
# 4  units         0          v115439168  1.1.1.1.5  61.0        NaN   NaN
#
#    TERMINATED  DECIMALS    ts_guid
# 0 NaN          0         000011124
# 1 NaN          0         000011124
# 2 NaN          0         000011124
# 3 NaN          1         000011124
# 4 NaN          1         000011124

# %%
# Obtain DGUIDs for each health region in Ontario
df2 = pd.read_csv('hbp-percent.csv')
df2.info()
df2 = df2.loc[df2['Province/Territory'] == 'Ontario']
df2.drop(['Province/Territory', 'hbp-percent', 'Data Comment'], axis = 1, inplace = True)

# Subset the DGUID so that it matches
df2['ts_guid'] = df2.DGUID.str[5:]
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 5 columns):
# DGUID                 108 non-null object
# Location              108 non-null object
# Province/Territory    108 non-null object
# hbp-percent           108 non-null object
# Data Comment          1 non-null object
# dtypes: object(5)
# memory usage: 4.3+ KB
#              DGUID                                                  Location  \
# 3    2017A00073551  City of Ottawa Health Unit
# 16   2017A00073595  City of Toronto Health Unit
# 17   2017A00073566  Wellington-Dufferin-Guelph Health Unit
# 21   2017A00073530  Durham Regional Health Unit
# 26   2017A00073544  Middlesex-London Health Unit
# 28   2017A00073560  Simcoe Muskoka District Health Unit
# 29   2017A00073552  Oxford County Health Unit
# 30   2017A00073534  Haldimand-Norfolk Health Unit
# 34   2017A00073570  York Regional Health Unit
# 35   2017A00073536  Halton Regional Health Unit
# 41   2017A00073537  City of Hamilton Health Unit
# 42   2017A00073565  Waterloo Health Unit
# 44   2017A00073527  Brant County Health Unit
# 47   2017A00073541  Kingston, Frontenac and Lennox and Addington Health Unit
# 48   2017A00073553  Peel Regional Health Unit
# 54   2017A00073554  Perth District Health Unit
# 58   2017A00073558  The Eastern Ontario Health Unit
# 63   2017A00073557  Renfrew County and District Health Unit
# 68   2017A00073542  Lambton Health Unit
# 70   2017A00073568  Windsor-Essex County Health Unit
# 71   2017A00073533  Grey Bruce Health Unit
# 74   2017A00073538  Hastings and Prince Edward Counties Health Unit
# 76   2017A00073555  Peterborough County - City Health Unit
# 77   2017A00073543  Leeds, Grenville and Lanark District Health Unit
# 79   2017A00073546  Niagara Regional Area Health Unit
# 81   2017A00073539  Huron County Health Unit
# 82   2017A00073549  Northwestern Health Unit
# 83   2017A00073547  North Bay Parry Sound District Health Unit
# 88   2017A00073561  Sudbury and District Health Unit
# 89   2017A00073531  Elgin-St. Thomas Health Unit
# 90   2017A00073562  Thunder Bay District Health Unit
# 94   2017A00073535  Haliburton, Kawartha, Pine Ridge District Health Unit
# 96   2017A00073556  Porcupine Health Unit
# 97   2017A00073526  The District of Algoma Health Unit
# 101  2017A00073563  Timiskaming Health Unit
# 102  2017A00073540  Chatham-Kent Health Unit
#
#       ts_guid
# 3    00073551
# 16   00073595
# 17   00073566
# 21   00073530
# 26   00073544
# 28   00073560
# 29   00073552
# 30   00073534
# 34   00073570
# 35   00073536
# 41   00073537
# 42   00073565
# 44   00073527
# 47   00073541
# 48   00073553
# 54   00073554
# 58   00073558
# 63   00073557
# 68   00073542
# 70   00073568
# 71   00073533
# 74   00073538
# 76   00073555
# 77   00073543
# 79   00073546
# 81   00073539
# 82   00073549
# 83   00073547
# 88   00073561
# 89   00073531
# 90   00073562
# 94   00073535
# 96   00073556
# 97   00073526
# 101  00073563
# 102  00073540

# %%
df3 = pd.merge(left = df2, right = df, how = 'left', left_on = 'ts_guid', right_on = 'ts_guid')
df3.info()
df3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269892 entries, 0 to 269891
# Data columns (total 21 columns):
# DGUID_x            269892 non-null object
# Location           269892 non-null object
# ts_guid            269892 non-null object
# REF_DATE           269892 non-null object
# GEO                269892 non-null object
# DGUID_y            269892 non-null object
# Age group          269892 non-null object
# Sex                269892 non-null object
# Indicators         269892 non-null object
# Characteristics    269892 non-null object
# UOM                269892 non-null object
# UOM_ID             269892 non-null int64
# SCALAR_FACTOR      269892 non-null object
# SCALAR_ID          269892 non-null int64
# VECTOR             269892 non-null object
# COORDINATE         269892 non-null object
# VALUE              189521 non-null float64
# STATUS             153136 non-null object
# SYMBOL             0 non-null float64
# TERMINATED         0 non-null float64
# DECIMALS           269892 non-null int64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 45.3+ MB
#          DGUID_x                    Location   ts_guid   REF_DATE  \
# 0  2017A00073551  City of Ottawa Health Unit  00073551  2015/2016
# 1  2017A00073551  City of Ottawa Health Unit  00073551  2015/2016
# 2  2017A00073551  City of Ottawa Health Unit  00073551  2015/2016
# 3  2017A00073551  City of Ottawa Health Unit  00073551  2015/2016
# 4  2017A00073551  City of Ottawa Health Unit  00073551  2015/2016
#
#                                    GEO        DGUID_y  \
# 0  City of Ottawa Health Unit, Ontario  2015A00073551
# 1  City of Ottawa Health Unit, Ontario  2015A00073551
# 2  City of Ottawa Health Unit, Ontario  2015A00073551
# 3  City of Ottawa Health Unit, Ontario  2015A00073551
# 4  City of Ottawa Health Unit, Ontario  2015A00073551
#
#                   Age group         Sex  \
# 0  Total, 12 years and over  Both sexes
# 1  Total, 12 years and over  Both sexes
# 2  Total, 12 years and over  Both sexes
# 3  Total, 12 years and over  Both sexes
# 4  Total, 12 years and over  Both sexes
#
#                                  Indicators  \
# 0  Perceived health, very good or excellent
# 1  Perceived health, very good or excellent
# 2  Perceived health, very good or excellent
# 3  Perceived health, very good or excellent
# 4  Perceived health, very good or excellent
#
#                                    Characteristics      UOM  UOM_ID  \
# 0  Number of persons                                Number   223
# 1  Low 95% confidence interval, number of persons   Number   223
# 2  High 95% confidence interval, number of persons  Number   223
# 3  Percent                                          Percent  239
# 4  Low 95% confidence interval, percent             Percent  239
#
#   SCALAR_FACTOR  SCALAR_ID      VECTOR  COORDINATE     VALUE STATUS  SYMBOL  \
# 0  units         0          v115627492  59.1.1.1.1  550200.0  NaN   NaN
# 1  units         0          v115627493  59.1.1.1.2  520400.0  NaN   NaN
# 2  units         0          v115627494  59.1.1.1.3  576400.0  NaN   NaN
# 3  units         0          v115627495  59.1.1.1.4  66.9      NaN   NaN
# 4  units         0          v115627496  59.1.1.1.5  63.3      NaN   NaN
#
#    TERMINATED  DECIMALS
# 0 NaN          0
# 1 NaN          0
# 2 NaN          0
# 3 NaN          1
# 4 NaN          1

# %%
# Subset the data
df3 = df3.loc[df3['Age group'] == 'Total, 12 years and over']
df3 = df3[df3.REF_DATE == '2017/2018']
df3 = df3[df3['Sex'] == 'Both sexes' ]

listofchar = ['Low 95% confidence interval, number of persons', 
              'High 95% confidence interval, number of persons', 
              'Low 95% confidence interval, percent',
              'High 95% confidence interval, percent', 
              'Statistically different from the Canada rate', 
              'Statistically different from the provincial rate', 
              'Statistically different from previous reference period']

for each in listofchar:
    df3 = df3[df3.Characteristics != each]

df3.head()
# Out:
#             DGUID_x                    Location   ts_guid   REF_DATE  \
# 3528  2017A00073551  City of Ottawa Health Unit  00073551  2017/2018
# 3531  2017A00073551  City of Ottawa Health Unit  00073551  2017/2018
# 3537  2017A00073551  City of Ottawa Health Unit  00073551  2017/2018
# 3540  2017A00073551  City of Ottawa Health Unit  00073551  2017/2018
# 3546  2017A00073551  City of Ottawa Health Unit  00073551  2017/2018
#
#                                       GEO        DGUID_y  \
# 3528  City of Ottawa Health Unit, Ontario  2015A00073551
# 3531  City of Ottawa Health Unit, Ontario  2015A00073551
# 3537  City of Ottawa Health Unit, Ontario  2015A00073551
# 3540  City of Ottawa Health Unit, Ontario  2015A00073551
# 3546  City of Ottawa Health Unit, Ontario  2015A00073551
#
#                      Age group         Sex  \
# 3528  Total, 12 years and over  Both sexes
# 3531  Total, 12 years and over  Both sexes
# 3537  Total, 12 years and over  Both sexes
# 3540  Total, 12 years and over  Both sexes
# 3546  Total, 12 years and over  Both sexes
#
#                                            Indicators    Characteristics  \
# 3528  Perceived health, very good or excellent         Number of persons
# 3531  Perceived health, very good or excellent         Percent
# 3537  Perceived health, fair or poor                   Number of persons
# 3540  Perceived health, fair or poor                   Percent
# 3546  Perceived mental health, very good or excellent  Number of persons
#
#           UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID      VECTOR  COORDINATE  \
# 3528  Number   223     units         0          v115627492  59.1.1.1.1
# 3531  Percent  239     units         0          v115627495  59.1.1.1.4
# 3537  Number   223     units         0          v115627500  59.1.1.2.1
# 3540  Percent  239     units         0          v115627503  59.1.1.2.4
# 3546  Number   223     units         0          v115627508  59.1.1.3.1
#
#          VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 3528  565300.0  NaN   NaN     NaN          0
# 3531  66.0      NaN   NaN     NaN          1
# 3537  65800.0   NaN   NaN     NaN          0
# 3540  7.7       NaN   NaN     NaN          1
# 3546  559400.0  NaN   NaN     NaN          0

# %%
# Drop columns that are not needed
listofcols = ['DGUID_x', 'GEO', 'Age group', 'Sex', 
              'SCALAR_FACTOR', 'SCALAR_ID', 'STATUS', 'SYMBOL', 
              'TERMINATED', 'DECIMALS', 'VECTOR', 'COORDINATE', 'UOM_ID']

df3.drop(listofcols, axis = 1, inplace = True)

# %%
df3.head()
# Out:
#                         Location   ts_guid   REF_DATE        DGUID_y  \
# 3528  City of Ottawa Health Unit  00073551  2017/2018  2015A00073551
# 3531  City of Ottawa Health Unit  00073551  2017/2018  2015A00073551
# 3537  City of Ottawa Health Unit  00073551  2017/2018  2015A00073551
# 3540  City of Ottawa Health Unit  00073551  2017/2018  2015A00073551
# 3546  City of Ottawa Health Unit  00073551  2017/2018  2015A00073551
#
#                                            Indicators    Characteristics  \
# 3528  Perceived health, very good or excellent         Number of persons
# 3531  Perceived health, very good or excellent         Percent
# 3537  Perceived health, fair or poor                   Number of persons
# 3540  Perceived health, fair or poor                   Percent
# 3546  Perceived mental health, very good or excellent  Number of persons
#
#           UOM     VALUE
# 3528  Number   565300.0
# 3531  Percent  66.0
# 3537  Number   65800.0
# 3540  Percent  7.7
# 3546  Number   559400.0

# %%
# Subset data, just numbers, and pivot
df_num = df3[df3.Characteristics == 'Number of persons']
df_num = df_num.pivot_table('VALUE', ['Location', 'ts_guid', 'REF_DATE', 'DGUID_y'], 'Indicators')
df_num.head(10)
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 36 entries, (Brant County Health Unit, 00073527, 2017/2018, 2015A00073527) to (York Regional Health Unit, 00073570, 2017/2018, 2015A00073570)
# Data columns (total 25 columns):
# Arthritis (15 years and over)                                                      36 non-null float64
# Asthma                                                                             36 non-null float64
# Body mass index, adjusted self-reported, adult (18 years and over), obese          36 non-null float64
# Body mass index, adjusted self-reported, adult (18 years and over), overweight     36 non-null float64
# Body mass index, self-reported, youth (12 to 17 years old), overweight or obese    29 non-null float64
# Breast milk feeding initiation                                                     35 non-null float64
# Chronic obstructive pulmonary disease (COPD; 35 years and over)                    36 non-null float64
# Current smoker, daily                                                              36 non-null float64
# Current smoker, daily or occasional                                                36 non-null float64
# Diabetes                                                                           36 non-null float64
# Exclusive breastfeeding, at least 6 months                                         13 non-null float64
# Has a regular healthcare provider                                                  36 non-null float64
# Heavy drinking                                                                     36 non-null float64
# High blood pressure                                                                36 non-null float64
# Influenza immunization in the past 12 months                                       36 non-null float64
# Life satisfaction, satisfied or very satisfied                                     36 non-null float64
# Mood disorder                                                                      36 non-null float64
# Perceived health, fair or poor                                                     36 non-null float64
# Perceived health, very good or excellent                                           36 non-null float64
# Perceived life stress, most days quite a bit or extremely stressful                36 non-null float64
# Perceived mental health, fair or poor                                              36 non-null float64
# Perceived mental health, very good or excellent                                    36 non-null float64
# Physical activity, 150 minutes per week, adult (18 years and over)                 36 non-null float64
# Physical activity, average 60 minutes per day, youth (12 to 17 years old)          36 non-null float64
# Sense of belonging to local community, somewhat strong or very strong              36 non-null float64
# dtypes: float64(25)
# memory usage: 8.4+ KB

# %%
# Subset data, just numbers, and pivot
df_percent = df3[df3.Characteristics == 'Percent']
df_percent.head()
df_percent = df_percent.pivot_table('VALUE', ['Location', 'ts_guid', 'REF_DATE', 'DGUID_y'], 'Indicators')
df_percent.head(10)
df_percent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 36 entries, (Brant County Health Unit, 00073527, 2017/2018, 2015A00073527) to (York Regional Health Unit, 00073570, 2017/2018, 2015A00073570)
# Data columns (total 25 columns):
# Arthritis (15 years and over)                                                      36 non-null float64
# Asthma                                                                             36 non-null float64
# Body mass index, adjusted self-reported, adult (18 years and over), obese          36 non-null float64
# Body mass index, adjusted self-reported, adult (18 years and over), overweight     36 non-null float64
# Body mass index, self-reported, youth (12 to 17 years old), overweight or obese    30 non-null float64
# Breast milk feeding initiation                                                     33 non-null float64
# Chronic obstructive pulmonary disease (COPD; 35 years and over)                    36 non-null float64
# Current smoker, daily                                                              36 non-null float64
# Current smoker, daily or occasional                                                36 non-null float64
# Diabetes                                                                           36 non-null float64
# Exclusive breastfeeding, at least 6 months                                         20 non-null float64
# Has a regular healthcare provider                                                  36 non-null float64
# Heavy drinking                                                                     36 non-null float64
# High blood pressure                                                                36 non-null float64
# Influenza immunization in the past 12 months                                       36 non-null float64
# Life satisfaction, satisfied or very satisfied                                     36 non-null float64
# Mood disorder                                                                      36 non-null float64
# Perceived health, fair or poor                                                     36 non-null float64
# Perceived health, very good or excellent                                           36 non-null float64
# Perceived life stress, most days quite a bit or extremely stressful                36 non-null float64
# Perceived mental health, fair or poor                                              36 non-null float64
# Perceived mental health, very good or excellent                                    36 non-null float64
# Physical activity, 150 minutes per week, adult (18 years and over)                 36 non-null float64
# Physical activity, average 60 minutes per day, youth (12 to 17 years old)          36 non-null float64
# Sense of belonging to local community, somewhat strong or very strong              36 non-null float64
# dtypes: float64(25)
# memory usage: 8.4+ KB

# %%
df_percent = df_percent.reset_index()
df_num = df_num.reset_index()
df_percent.to_csv(r'comorbidities_percent.csv', index = False)
df_num.to_csv(r'comorbidities_num.csv', index = False)
