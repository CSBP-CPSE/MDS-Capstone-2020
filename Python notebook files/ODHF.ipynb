# %%
# importing the ODHF dataset

import pandas as pd

# %%
df = pd.read_csv('/Users/Sofia/Desktop/ODHF/odhf_v1.csv', engine='python')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9039 entries, 0 to 9038
# Data columns (total 17 columns):
# index                        9039 non-null int64
# facility_name                9039 non-null object
# source_facility_type         7449 non-null object
# odhf_facility_type           9026 non-null object
# provider                     9039 non-null object
# unit                         3 non-null object
# street_no                    7495 non-null object
# street_name                  7571 non-null object
# postal_code                  8877 non-null object
# city                         8934 non-null object
# province                     9039 non-null object
# source_format_str_address    4626 non-null object
# CSDname                      8651 non-null object
# CSDuid                       7525 non-null float64
# Pruid                        9039 non-null int64
# latitude                     7543 non-null float64
# longitude                    7543 non-null float64
# ...

# %%
# checking number of provinces, then filtering to keep only ontario

df.groupby('province').nunique()
# Out:
#           index  facility_name  source_facility_type  odhf_facility_type  \
# province
# ab          331            331                    12                   3
# bc         1492           1492                    11                   3
# mb          214            214                     8                   3
# nb           62             62                     6                   3
# nl           96             96                     7                   3
# ns          195            195                    15                   3
# nt            7              7                     2                   2
# nu            3              3                     1                   1
# on         3733           3732                    30                   3
# pe           35             35                    12                   3
# qc         2359           2358                    21                   3
# sk          473            473                    58                   3
# ...

# %%
ont =  df['province']=='on'

df_ont = df[ont]
print(df_ont.shape)
# Out:
# (3733, 17)

# %%
df_ont.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3733 entries, 2400 to 6132
# Data columns (total 17 columns):
# index                        3733 non-null int64
# facility_name                3733 non-null object
# source_facility_type         3705 non-null object
# odhf_facility_type           3728 non-null object
# provider                     3733 non-null object
# unit                         0 non-null object
# street_no                    3122 non-null object
# street_name                  3154 non-null object
# postal_code                  3726 non-null object
# city                         3724 non-null object
# province                     3733 non-null object
# source_format_str_address    271 non-null object
# CSDname                      3540 non-null object
# CSDuid                       3151 non-null float64
# Pruid                        3733 non-null int64
# latitude                     3159 non-null float64
# longitude                    3159 non-null float64
# ...

# %%
df_ont.groupby('odhf_facility_type').count()
# Out:
#                                          index  facility_name  \
# odhf_facility_type
# Ambulatory health care services           1104           1104
# Hospitals                                  520            520
# Nursing and residential care facilities   2104           2104
#
#                                          source_facility_type  provider  unit  \
# odhf_facility_type
# Ambulatory health care services                          1104      1104     0
# Hospitals                                                 492       520     0
# Nursing and residential care facilities                  2104      2104     0
#
#                                          street_no  street_name  postal_code  \
# odhf_facility_type
# Ambulatory health care services               1058         1079         1100
# Hospitals                                      396          401          520
# Nursing and residential care facilities       1663         1669         2101
#
# ...

# %%
df_ont.groupby('odhf_facility_type').count()
# Out:
#                                          index  facility_name  \
# odhf_facility_type
# Ambulatory health care services           1104           1104
# Hospitals                                  520            520
# Nursing and residential care facilities   2104           2104
#
#                                          source_facility_type  provider  unit  \
# odhf_facility_type
# Ambulatory health care services                          1104      1104     0
# Hospitals                                                 492       520     0
# Nursing and residential care facilities                  2104      2104     0
#
#                                          street_no  street_name  postal_code  \
# odhf_facility_type
# Ambulatory health care services               1058         1079         1100
# Hospitals                                      396          401          520
# Nursing and residential care facilities       1663         1669         2101
#
# ...

# %%
# checking why the length of the odhf_facility_type is not equal to the length of the data. 
# There are some Na's in the column. The corresponding facilities are mental health or psychiatric. 

some_values = ['Ambulatory health care services', 'Hospitals', 'Nursing and residential care facilities']
df_ont.loc[~df_ont['odhf_facility_type'].isin(some_values)]


# drop the rows which aren't LTC odhf_Facility_type, because they all belong to mental health (not part of this project)
# Out:
#       index                                      facility_name  \
# 4618   4619                           oaklands regional centre
# 4916   4917               regional mental health care - london
# 4942   4943               regional treatment centre (kingston)
# 5378   5379                       southwestern regional centre
# 5733   5734  thistletown regional centre for children and a...
#
#      source_facility_type odhf_facility_type                        provider  \
# 4618        mental health                NaN  Public Health Agency of Canada
# 4916          psychiatric                NaN  Public Health Agency of Canada
# 4942          psychiatric                NaN  Public Health Agency of Canada
# 5378        mental health                NaN  Public Health Agency of Canada
# 5733          psychiatric                NaN  Public Health Agency of Canada
#
#      unit street_no       street_name postal_code      city province  \
# ...

# %%
df_ont.groupby('source_facility_type').count()
# Out:
#                                           index  facility_name  \
# source_facility_type
# active acute hospital                        70             70
# active acute hospital, long term care        47             47
# aids bureau                                  17             17
# cancer                                        3              3
# cardiology                                    1              1
# children's treatment centre                  27             27
# chronic care                                 22             22
# community health centre                      34             34
# community support service                   806            806
# extended care                                 1              1
# family health team - contract               178            178
# general                                     174            174
# hospital - corporation                       65             65
# ...

# %%
LTC = df_ont[(df_ont['source_facility_type']=='long-term care home') | (df_ont['source_facility_type']=='long term care')]

LTC
# Out:
#       index                                      facility_name  \
# 2434   2435          afton park place long term care community
# 2438   2439                                   albright gardens
# 2439   2440                                     albright manor
# 2441   2442                                    alexander place
# 2448   2449                          algoma manor nursing home
# 2455   2456                             algonquin nursing home
# 2458   2459                                          allendale
# 2460   2461                              almonte country haven
# 2465   2466                            altamont care community
# 2539   2540                            anson place care centre
# 2540   2541    aon inc. � centennial place long term care home
# 2541   2542                             aon inc. � moira place
# 2542   2543             apans health services � copper terrace
# 2543   2544       apans health services � grace villa hamilton
# ...

# %%
LTC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1012 entries, 2434 to 6132
# Data columns (total 17 columns):
# index                        1012 non-null int64
# facility_name                1012 non-null object
# source_facility_type         1012 non-null object
# odhf_facility_type           1012 non-null object
# provider                     1012 non-null object
# unit                         0 non-null object
# street_no                    582 non-null object
# street_name                  584 non-null object
# postal_code                  1012 non-null object
# city                         1009 non-null object
# province                     1012 non-null object
# source_format_str_address    0 non-null object
# CSDname                      854 non-null object
# CSDuid                       583 non-null float64
# Pruid                        1012 non-null int64
# latitude                     584 non-null float64
# longitude                    584 non-null float64
# ...
